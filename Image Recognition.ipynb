# %% [markdown]
# # Testing facial recognition libraries

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\Grimmethy /.deepface created
# Directory  C:\Users\Grimmethy /.deepface/weights created

# %%
obj = DeepFace.analyze(img_path = r"C:\Users\Grimmethy\Pictures\Camera Roll\WIN_20210827_04_31_05_Pro.jpg", actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Grimmethy\.deepface\weights\gender_model_weights.h5
#
#   0%|          | 0.00/537M [00:00<?, ?B/s]
#   0%|          | 524k/537M [00:00<07:09, 1.25MB/s]
#   0%|          | 1.05M/537M [00:00<07:19, 1.22MB/s]
#   0%|          | 1.57M/537M [00:01<07:19, 1.22MB/s]
#   0%|          | 2.10M/537M [00:01<07:19, 1.22MB/s]
#   0%|          | 2.62M/537M [00:02<07:22, 1.21MB/s]
#   1%|          | 3.15M/537M [00:02<07:21, 1.21MB/s]
#   1%|          | 3.67M/537M [00:03<07:21, 1.21MB/s]
#   1%|          | 4.19M/537M [00:03<07:22, 1.20MB/s]
#   1%|          | 4.72M/537M [00:03<07:21, 1.20MB/s]
#   1%|          | 5.24M/537M [00:04<07:20, 1.21MB/s]
#   1%|          | 5.77M/537M [00:04<07:19, 1.21MB/s]
#   1%|          | 6.29M/537M [00:05<07:20, 1.21MB/s]
#   1%|▏         | 6.82M/537M [00:05<07:23, 1.19MB/s]
# ...

# %%
obj
# Out:
# {'age': 28,
#  'region': {'x': 797, 'y': 408, 'w': 341, 'h': 341},
#  'gender': 'Man',
#  'race': {'asian': 1.3834273442626,
#   'indian': 3.7729334086179733,
#   'black': 0.7615650072693825,
#   'white': 37.59373128414154,
#   'middle eastern': 24.78136271238327,
#   'latino hispanic': 31.706979870796204},
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.09435046793746757,
#   'disgust': 0.0005013250600812526,
#   'fear': 0.0027318779566815952,
#   'happy': 96.03307819563616,
#   'sad': 0.007879773799148875,
#   'surprise': 0.09755435166273127,
#   'neutral': 3.7639042743387385},
#  'dominant_emotion': 'happy'}

# %%
result = DeepFace.verify(r"C:\Users\Grimmethy\Pictures\Camera Roll\WIN_20210827_04_31_05_Pro.jpg", r"C:\Users\Grimmethy\Pictures\Pic.png")
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\Grimmethy\.deepface\weights\vgg_face_weights.h5
#
#   0%|          | 0.00/580M [00:00<?, ?B/s]
#   0%|          | 524k/580M [00:00<07:41, 1.26MB/s]
#   0%|          | 1.05M/580M [00:00<07:46, 1.24MB/s]
#   0%|          | 1.57M/580M [00:01<07:49, 1.23MB/s]
#   0%|          | 2.10M/580M [00:01<07:52, 1.22MB/s]
#   0%|          | 2.62M/580M [00:02<07:53, 1.22MB/s]
#   1%|          | 3.15M/580M [00:02<07:53, 1.22MB/s]
#   1%|          | 3.67M/580M [00:03<07:54, 1.22MB/s]
#   1%|          | 4.19M/580M [00:03<07:55, 1.21MB/s]
#   1%|          | 4.72M/580M [00:03<07:55, 1.21MB/s]
#   1%|          | 5.24M/580M [00:04<07:54, 1.21MB/s]
#   1%|          | 5.77M/580M [00:04<07:53, 1.21MB/s]
#   1%|          | 6.29M/580M [00:05<07:53, 1.21MB/s]
#   1%|          | 6.82M/580M [00:05<07:53, 1.21MB/s]
# ...

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.32333899758864737,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
obj = DeepFace.analyze(img_path = r"C:\Users\Grimmethy\Desktop\LMTCHEATIMGS\Amr.png", actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# ...
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f325992bd11c> in <module>
# ----> 1 obj = DeepFace.analyze(img_path = r"C:\Users\Grimmethy\Desktop\LMTCHEATIMGS\Amr.png", actions = ['age', 'gender', 'race', 'emotion'])
#
# ~\AppData\Roaming\Python\Python37\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     402                         elif action == 'age':
#     403                                 if img_224 is None:
# --> 404                                         img_224, region = functions.preprocess_face(img = img_path, target_size = (224, 224), grayscale = False, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     405
# ...

# %%
obj
# Out:
# {'age': 29,
#  'region': {'x': 86, 'y': 65, 'w': 76, 'h': 76},
#  'gender': 'Woman',
#  'race': {'asian': 17.955513298511505,
#   'indian': 0.6738724652677774,
#   'black': 0.13690346386283636,
#   'white': 59.29082632064819,
#   'middle eastern': 6.884748488664627,
#   'latino hispanic': 15.058140456676483},
#  'dominant_race': 'white',
#  'emotion': {'angry': 8.72718156289089e-05,
#   'disgust': 4.062653117356373e-12,
#   'fear': 1.0117863118000692e-07,
#   'happy': 99.9608457135146,
#   'sad': 8.568582154872547e-07,
#   'surprise': 0.00814211792457747,
#   'neutral': 0.030924323752230556},
#  'dominant_emotion': 'happy'}
