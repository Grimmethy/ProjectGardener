# %%
## import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

img = cv.imread(r"D:\Users\Grimmethy\Downloads\20210522_114502.jpg",0)
edges = cv.Canny(img,20,35)

blurred = cv.GaussianBlur(img, (5, 5), cv.BORDER_DEFAULT)

edge2 = cv.Canny(blurred,10,20)

# show the original and blurred images
cv.imshow("Original", image)
cv.imshow("Blurred", blurred)

figure(figsize=(15, 10), dpi=80)
plt.subplot(221),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(222),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.subplot(223),plt.imshow(blurred,cmap = 'gray')
plt.title('Blurred Image'), plt.xticks([]), plt.yticks([])

plt.subplot(224),plt.imshow(edge2,cmap = 'gray')
plt.title('Blurred Image'), plt.xticks([]), plt.yticks([])

plt.show()
