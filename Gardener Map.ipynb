# %%
from arcgis.gis import GIS
gis = GIS()
m = gis.map()
map1 = gis.map("Seattle, WA")
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-937a851e-27b2-439c-9efc-29c2315dcda6"><img src=""></img></div>

# %%
from arcgis.gis import GIS


import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-d053a01c24c9> in <module>
#       1 from arcgis.gis import GIS
# ----> 2 import arcpy
#       3
#       4 import geopandas as gpd
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'arcpy'

# %%
map1 = gis.map("Palm Springs, CA")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29057fe37e10> in <module>
# ----> 1 map1 = gis.map("Palm Springs, CA")
#
# NameError: name 'gis' is not defined

# %%
# load zip code shape data
zip_codes_gdf = gpd.read_file('data/shapes/Zip_Codes.shp')
zip_codes_gdf.head()
# Out:
#    OBJECTID    ZIP ZIPCODE COUNTY     SHAPE_Leng    SHAPE_Area  \
# 0         1  98031   98031    033  117508.211718  2.280129e+08
# 1         2  98032   98032    033  166737.664791  4.826754e+08
# 2         3  98033   98033    033  101363.840369  2.566747e+08
# 3         4  98034   98034    033   98550.452509  2.725072e+08
# 4         5  98030   98030    033   94351.264837  2.000954e+08
#
#                                             geometry
# 0  POLYGON ((-122.21842 47.43750, -122.21935 47.4...
# 1  MULTIPOLYGON (((-122.24187 47.44122, -122.2411...
# 2  POLYGON ((-122.20571 47.65170, -122.20511 47.6...
# 3  POLYGON ((-122.17551 47.73706, -122.17554 47.7...
# 4  POLYGON ((-122.16746 47.38549, -122.16746 47.3...

# %%
zip_codes_gdf.plot()

# %%
# load seattle shape
cities = gpd.read_file('data/shapes/Municipal_Boundaries.shp')
seattle = cities.loc[cities['CITYNAME'] == 'Seattle']
seattle = seattle.reset_index()
seattle_shp = seattle.loc[0, 'geometry']

# %%
# load seattle waterfront shape
waterfront = gpd.read_file('data/shapes/City_of_Seattle_Shoreline.shp')

# %%
waterfront.plot();
